# %%
# !pip install pandas numpy scikit-learn seaborn tabulate

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

# %%
df =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Share Share shipping  dataset.xlsx - shipping.csv')
df
# Out:
#       ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0      1               D           Flight                    4
# 1      2               F           Flight                    4
# 2      3               A           Flight                    2
# 3      4               B           Flight                    3
# 4      5               C           Flight                    2
# ..   ...             ...              ...                  ...
# 392  393               A             Road                    4
# 393  394               B             Road                    5
# 394  395               C             Road                    3
# 395  396               F             Road                    4
# 396  397               D             Road                    3
#
#      Customer_rating  Cost_of_the_Product  Prior_purchases Product_importance  \
# 0                  2                  177                3                low
# ...

# %%
df.shape
# Out:
# (397, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   397 non-null    int64
#  1   Warehouse_block      397 non-null    object
#  2   Mode_of_Shipment     397 non-null    object
#  3   Customer_care_calls  397 non-null    int64
#  4   Customer_rating      397 non-null    int64
#  5   Cost_of_the_Product  397 non-null    int64
#  6   Prior_purchases      397 non-null    int64
#  7   Product_importance   397 non-null    object
#  8   Discount_offered     397 non-null    int64
#  9   Weight_in_gms        397 non-null    int64
# dtypes: int64(7), object(3)
# memory usage: 31.1+ KB

# %%
df.describe()
# Out:
#                ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  397.000000           397.000000       397.000000           397.000000
# mean   199.000000             3.498741         3.098237           188.246851
# std    114.748275             1.050793         1.424150            45.101675
# min      1.000000             2.000000         1.000000            97.000000
# 25%    100.000000             3.000000         2.000000           150.000000
# 50%    199.000000             3.000000         3.000000           181.000000
# 75%    298.000000             4.000000         4.000000           225.000000
# max    397.000000             7.000000         5.000000           294.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms
# count       397.000000        397.000000     397.000000
# mean          3.118388         33.765743    2345.914358
# std           1.055811         18.794154    1116.759140
# ...

# %%
df['Weight_in_gms'].describe()
# Out:
# count     397.000000
# mean     2345.914358
# std      1116.759140
# min      1009.000000
# 25%      1511.000000
# 50%      2026.000000
# 75%      3054.000000
# max      7846.000000
# Name: Weight_in_gms, dtype: float64

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Discount_offered       0
# Weight_in_gms          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Discount_offered', 'Weight_in_gms'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Discount_offered        int64
# Weight_in_gms           int64
# dtype: object

# %%
df= df.apply(pd.to_numeric, errors= 'coerce')
df
# Out:
#       ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0      1              NaN               NaN                    4
# 1      2              NaN               NaN                    4
# 2      3              NaN               NaN                    2
# 3      4              NaN               NaN                    3
# 4      5              NaN               NaN                    2
# ..   ...              ...               ...                  ...
# 392  393              NaN               NaN                    4
# 393  394              NaN               NaN                    5
# 394  395              NaN               NaN                    3
# 395  396              NaN               NaN                    4
# 396  397              NaN               NaN                    3
#
#      Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                  2                  177                3
# 1                  5                  216                2
# ...

# %%
df.mean()
# Out:
# ID                      199.000000
# Warehouse_block                NaN
# Mode_of_Shipment               NaN
# Customer_care_calls       3.498741
# Customer_rating           3.098237
# Cost_of_the_Product     188.246851
# Prior_purchases           3.118388
# Product_importance             NaN
# Discount_offered         33.765743
# Weight_in_gms          2345.914358
# dtype: float64

# %%
num_col =['Customer_care_calls', 'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases', 'Discount_offered', 'Weight_in_gms']
num_col
# Out:
# ['Customer_care_calls',
#  'Customer_rating',
#  'Cost_of_the_Product',
#  'Prior_purchases',
#  'Discount_offered',
#  'Weight_in_gms']

# %%
df.hist(bins ='auto', figsize=(15, 10), color= 'purple',alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df.boxplot(column= ['Customer_care_calls', 'Customer_rating'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Cost_of_the_Product',y='Prior_purchases', data=df)
plt.title('Cost_of_the_Product vs Prior_purchases')
plt.xlabel('Cost_of_the_Product')
plt.ylabel('Prior_purchases')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVR, SVC
from sklearn.metrics import mean_squared_error, r2_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df[['Customer_care_calls',
 'Customer_rating',
 'Cost_of_the_Product',
 'Prior_purchases',
 'Discount_offered',
 'Weight_in_gms']].corr()
# Out:
#                      Customer_care_calls  Customer_rating  \
# Customer_care_calls             1.000000        -0.034510
# Customer_rating                -0.034510         1.000000
# Cost_of_the_Product             0.247616        -0.018188
# Prior_purchases                 0.062729        -0.064855
# Discount_offered                0.019613        -0.052444
# Weight_in_gms                   0.108862        -0.033243
#
#                      Cost_of_the_Product  Prior_purchases  Discount_offered  \
# Customer_care_calls             0.247616         0.062729          0.019613
# Customer_rating                -0.018188        -0.064855         -0.052444
# Cost_of_the_Product             1.000000        -0.013979          0.012658
# Prior_purchases                -0.013979         1.000000          0.024435
# Discount_offered                0.012658         0.024435          1.000000
# Weight_in_gms                   0.639729        -0.109656         -0.011164
#
# ...

# %%
sns.heatmap(df[['Customer_care_calls',
 'Customer_rating',
 'Cost_of_the_Product',
 'Prior_purchases',
 'Discount_offered',
 'Weight_in_gms']].corr(), vmax=.3, center=0, cmap='coolwarm', square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >
